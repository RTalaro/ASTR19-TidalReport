# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\emmag\Documents\astro 19\BetterData - ASTR19_S22_group_project_data.csv", names=["Day","Time","Tide Height"], header=1,parse_dates=[["Day","Time"]])

# %% [markdown]
# I totally get if you guys don't want to use Pandas, but if you're willing to follow my lead on it, it'll make things much easier, since it's specifically designed for this sort of thing.

# %%
x=data["Day_Time"]
y=data["Tide Height"]

# %%
#This plots the data as both a scatter and line graph. 
#I wanted to show how there's both the small oscillation and the large oscillation as the tides get more extreme.
plt.figure(figsize=(20,2)) 
plt.scatter(x,y)
plt.plot(x,y)
